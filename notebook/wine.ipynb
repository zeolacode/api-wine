# %% [markdown]
# # Imports

# %%
import mlflow
import pandas as pd
from pycaret.classification import *
from sklearn.datasets import load_wine

# %%
mlflow.autolog()
# Out:
# 2024/09/19 21:52:00 INFO mlflow.tracking.fluent: Autologging successfully enabled for xgboost.
# 2024/09/19 21:52:01 WARNING mlflow.utils.autologging_utils: MLflow statsmodels autologging is known to be compatible with 0.11.1 <= statsmodels <= 0.14.2, but the installed version is 0.14.3. If you encounter errors during autologging, try upgrading / downgrading statsmodels to a compatible version, or try upgrading MLflow.
# 2024/09/19 21:52:03 INFO mlflow.tracking.fluent: Autologging successfully enabled for statsmodels.
# 2024/09/19 21:52:05 INFO mlflow.tracking.fluent: Autologging successfully enabled for sklearn.
# 2024/09/19 21:52:05 INFO mlflow.tracking.fluent: Autologging successfully enabled for lightgbm.

# %% [markdown]
# # Load and processing data raw

# %%
def load_wine_dataset() -> pd.DataFrame:
    """
    Load the wine dataset and return it as a pandas DataFrame.

    Returns:
        pd.DataFrame: The wine dataset as a pandas DataFrame.
    """
    wine_data = load_wine()
    df_raw = pd.DataFrame(wine_data.data, columns=wine_data.feature_names)
    df_raw['target'] = wine_data.target
    
    return df_raw

# %%
def processing_data_raw(df_raw: pd.DataFrame) -> pd.DataFrame:
    """
    Process the raw DataFrame by renaming a column and creating a copy.

    Args:
        df_raw (pd.DataFrame): The raw DataFrame to be processed.

    Returns:
        pd.DataFrame: The processed DataFrame.
    """
    df = df_raw.rename(
        columns={'od280/od315_of_diluted_wines': 'od280_od315_of_diluted_wines'}
    ).copy()
    
    return df

# %%
df_raw = load_wine_dataset()
df = processing_data_raw(df_raw)

# %%
df.head()
# Out:
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0    14.23        1.71  2.43               15.6      127.0           2.80
# 1    13.20        1.78  2.14               11.2      100.0           2.65
# 2    13.16        2.36  2.67               18.6      101.0           2.80
# 3    14.37        1.95  2.50               16.8      113.0           3.85
# 4    13.24        2.59  2.87               21.0      118.0           2.80
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    od280_od315_of_diluted_wines  proline  target
# 0                          3.92   1065.0       0
# 1                          3.40   1050.0       0
# 2                          3.17   1185.0       0
# 3                          3.45   1480.0       0
# 4                          2.93    735.0       0

# %% [markdown]
# # Setup Pipeline

# %%
# This function initializes the training environment and creates the transformation pipeline.
s = setup(
        df,
        target = 'target',
        train_size = 0.7,
        session_id = 123,
        normalize = True,
        log_experiment = True,
        experiment_name = 'wine'
    )
# Out:
# <style type="text/css">
# #T_710c9_row8_col1, #T_710c9_row12_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_710c9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_710c9_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_710c9_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_710c9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_710c9_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_710c9_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_710c9_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_710c9_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_710c9_row1_col1" class="data row1 col1" >target</td>
#     </tr>
#     <tr>
#       <th id="T_710c9_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_710c9_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_710c9_row2_col1" class="data row2 col1" >Multiclass</td>
#     </tr>
#     <tr>
#       <th id="T_710c9_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_710c9_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_710c9_row3_col1" class="data row3 col1" >(178, 14)</td>
#     </tr>
#     <tr>
#       <th id="T_710c9_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_710c9_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_710c9_row4_col1" class="data row4 col1" >(178, 14)</td>
#     </tr>
#     <tr>
#       <th id="T_710c9_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_710c9_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_710c9_row5_col1" class="data row5 col1" >(124, 14)</td>
#     </tr>
#     <tr>
#       <th id="T_710c9_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_710c9_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_710c9_row6_col1" class="data row6 col1" >(54, 14)</td>
#     </tr>
#     <tr>
#       <th id="T_710c9_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_710c9_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_710c9_row7_col1" class="data row7 col1" >13</td>
#     </tr>
#     <tr>
#       <th id="T_710c9_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_710c9_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_710c9_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_710c9_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_710c9_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_710c9_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_710c9_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_710c9_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_710c9_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_710c9_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_710c9_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_710c9_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_710c9_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_710c9_row12_col0" class="data row12 col0" >Normalize</td>
#       <td id="T_710c9_row12_col1" class="data row12 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_710c9_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_710c9_row13_col0" class="data row13 col0" >Normalize method</td>
#       <td id="T_710c9_row13_col1" class="data row13 col1" >zscore</td>
#     </tr>
#     <tr>
#       <th id="T_710c9_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_710c9_row14_col0" class="data row14 col0" >Fold Generator</td>
#       <td id="T_710c9_row14_col1" class="data row14 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_710c9_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_710c9_row15_col0" class="data row15 col0" >Fold Number</td>
#       <td id="T_710c9_row15_col1" class="data row15 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_710c9_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_710c9_row16_col0" class="data row16 col0" >CPU Jobs</td>
#       <td id="T_710c9_row16_col1" class="data row16 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_710c9_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_710c9_row17_col0" class="data row17 col0" >Use GPU</td>
#       <td id="T_710c9_row17_col1" class="data row17 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_710c9_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_710c9_row18_col0" class="data row18 col0" >Log Experiment</td>
#       <td id="T_710c9_row18_col1" class="data row18 col1" >MlflowLogger</td>
#     </tr>
#     <tr>
#       <th id="T_710c9_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_710c9_row19_col0" class="data row19 col0" >Experiment Name</td>
#       <td id="T_710c9_row19_col1" class="data row19 col1" >wine</td>
#     </tr>
#     <tr>
#       <th id="T_710c9_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_710c9_row20_col0" class="data row20 col0" >USI</td>
#       <td id="T_710c9_row20_col1" class="data row20 col1" >7eef</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Compare Models

# %%
# Train and evaluate all models in the model library.
best = compare_models()
# Out:
# <style type="text/css">
# #T_4be0d th {
#   text-align: left;
# }
# #T_4be0d_row0_col0, #T_4be0d_row1_col0, #T_4be0d_row1_col1, #T_4be0d_row1_col2, #T_4be0d_row1_col3, #T_4be0d_row1_col4, #T_4be0d_row1_col5, #T_4be0d_row1_col6, #T_4be0d_row1_col7, #T_4be0d_row2_col0, #T_4be0d_row2_col1, #T_4be0d_row2_col2, #T_4be0d_row2_col3, #T_4be0d_row2_col4, #T_4be0d_row2_col5, #T_4be0d_row2_col6, #T_4be0d_row2_col7, #T_4be0d_row3_col0, #T_4be0d_row3_col1, #T_4be0d_row3_col2, #T_4be0d_row3_col3, #T_4be0d_row3_col4, #T_4be0d_row3_col5, #T_4be0d_row3_col6, #T_4be0d_row3_col7, #T_4be0d_row4_col0, #T_4be0d_row4_col1, #T_4be0d_row4_col2, #T_4be0d_row4_col3, #T_4be0d_row4_col4, #T_4be0d_row4_col5, #T_4be0d_row4_col6, #T_4be0d_row4_col7, #T_4be0d_row5_col0, #T_4be0d_row5_col1, #T_4be0d_row5_col2, #T_4be0d_row5_col3, #T_4be0d_row5_col4, #T_4be0d_row5_col5, #T_4be0d_row5_col6, #T_4be0d_row5_col7, #T_4be0d_row6_col0, #T_4be0d_row6_col1, #T_4be0d_row6_col2, #T_4be0d_row6_col3, #T_4be0d_row6_col4, #T_4be0d_row6_col5, #T_4be0d_row6_col6, #T_4be0d_row6_col7, #T_4be0d_row7_col0, #T_4be0d_row7_col1, #T_4be0d_row7_col2, #T_4be0d_row7_col3, #T_4be0d_row7_col4, #T_4be0d_row7_col5, #T_4be0d_row7_col6, #T_4be0d_row7_col7, #T_4be0d_row8_col0, #T_4be0d_row8_col1, #T_4be0d_row8_col2, #T_4be0d_row8_col3, #T_4be0d_row8_col4, #T_4be0d_row8_col5, #T_4be0d_row8_col6, #T_4be0d_row8_col7, #T_4be0d_row9_col0, #T_4be0d_row9_col1, #T_4be0d_row9_col2, #T_4be0d_row9_col3, #T_4be0d_row9_col4, #T_4be0d_row9_col5, #T_4be0d_row9_col6, #T_4be0d_row9_col7, #T_4be0d_row10_col0, #T_4be0d_row10_col1, #T_4be0d_row10_col2, #T_4be0d_row10_col3, #T_4be0d_row10_col4, #T_4be0d_row10_col5, #T_4be0d_row10_col6, #T_4be0d_row10_col7, #T_4be0d_row11_col0, #T_4be0d_row11_col1, #T_4be0d_row11_col2, #T_4be0d_row11_col3, #T_4be0d_row11_col4, #T_4be0d_row11_col5, #T_4be0d_row11_col6, #T_4be0d_row11_col7, #T_4be0d_row12_col0, #T_4be0d_row12_col1, #T_4be0d_row12_col2, #T_4be0d_row12_col3, #T_4be0d_row12_col4, #T_4be0d_row12_col5, #T_4be0d_row12_col6, #T_4be0d_row12_col7, #T_4be0d_row13_col0, #T_4be0d_row13_col1, #T_4be0d_row13_col2, #T_4be0d_row13_col3, #T_4be0d_row13_col4, #T_4be0d_row13_col5, #T_4be0d_row13_col6, #T_4be0d_row13_col7, #T_4be0d_row14_col0, #T_4be0d_row14_col1, #T_4be0d_row14_col2, #T_4be0d_row14_col3, #T_4be0d_row14_col4, #T_4be0d_row14_col5, #T_4be0d_row14_col6, #T_4be0d_row14_col7, #T_4be0d_row15_col0, #T_4be0d_row15_col1, #T_4be0d_row15_col2, #T_4be0d_row15_col3, #T_4be0d_row15_col4, #T_4be0d_row15_col5, #T_4be0d_row15_col6, #T_4be0d_row15_col7 {
#   text-align: left;
# }
# #T_4be0d_row0_col1, #T_4be0d_row0_col2, #T_4be0d_row0_col3, #T_4be0d_row0_col4, #T_4be0d_row0_col5, #T_4be0d_row0_col6, #T_4be0d_row0_col7 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_4be0d_row0_col8, #T_4be0d_row1_col8, #T_4be0d_row2_col8, #T_4be0d_row4_col8, #T_4be0d_row5_col8, #T_4be0d_row6_col8, #T_4be0d_row7_col8, #T_4be0d_row8_col8, #T_4be0d_row9_col8, #T_4be0d_row10_col8, #T_4be0d_row11_col8, #T_4be0d_row12_col8, #T_4be0d_row13_col8, #T_4be0d_row14_col8, #T_4be0d_row15_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_4be0d_row3_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_4be0d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4be0d_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_4be0d_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_4be0d_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_4be0d_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_4be0d_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_4be0d_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_4be0d_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_4be0d_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_4be0d_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4be0d_level0_row0" class="row_heading level0 row0" >et</th>
#       <td id="T_4be0d_row0_col0" class="data row0 col0" >Extra Trees Classifier</td>
#       <td id="T_4be0d_row0_col1" class="data row0 col1" >1.0000</td>
#       <td id="T_4be0d_row0_col2" class="data row0 col2" >1.0000</td>
#       <td id="T_4be0d_row0_col3" class="data row0 col3" >1.0000</td>
#       <td id="T_4be0d_row0_col4" class="data row0 col4" >1.0000</td>
#       <td id="T_4be0d_row0_col5" class="data row0 col5" >1.0000</td>
#       <td id="T_4be0d_row0_col6" class="data row0 col6" >1.0000</td>
#       <td id="T_4be0d_row0_col7" class="data row0 col7" >1.0000</td>
#       <td id="T_4be0d_row0_col8" class="data row0 col8" >0.1690</td>
#     </tr>
#     <tr>
#       <th id="T_4be0d_level0_row1" class="row_heading level0 row1" >svm</th>
#       <td id="T_4be0d_row1_col0" class="data row1 col0" >SVM - Linear Kernel</td>
#       <td id="T_4be0d_row1_col1" class="data row1 col1" >0.9917</td>
#       <td id="T_4be0d_row1_col2" class="data row1 col2" >0.0000</td>
#       <td id="T_4be0d_row1_col3" class="data row1 col3" >0.9917</td>
#       <td id="T_4be0d_row1_col4" class="data row1 col4" >0.9933</td>
#       <td id="T_4be0d_row1_col5" class="data row1 col5" >0.9917</td>
#       <td id="T_4be0d_row1_col6" class="data row1 col6" >0.9874</td>
#       <td id="T_4be0d_row1_col7" class="data row1 col7" >0.9883</td>
#       <td id="T_4be0d_row1_col8" class="data row1 col8" >0.0510</td>
#     </tr>
#     <tr>
#       <th id="T_4be0d_level0_row2" class="row_heading level0 row2" >ridge</th>
#       <td id="T_4be0d_row2_col0" class="data row2 col0" >Ridge Classifier</td>
#       <td id="T_4be0d_row2_col1" class="data row2 col1" >0.9917</td>
#       <td id="T_4be0d_row2_col2" class="data row2 col2" >0.0000</td>
#       <td id="T_4be0d_row2_col3" class="data row2 col3" >0.9917</td>
#       <td id="T_4be0d_row2_col4" class="data row2 col4" >0.9938</td>
#       <td id="T_4be0d_row2_col5" class="data row2 col5" >0.9918</td>
#       <td id="T_4be0d_row2_col6" class="data row2 col6" >0.9875</td>
#       <td id="T_4be0d_row2_col7" class="data row2 col7" >0.9884</td>
#       <td id="T_4be0d_row2_col8" class="data row2 col8" >0.0550</td>
#     </tr>
#     <tr>
#       <th id="T_4be0d_level0_row3" class="row_heading level0 row3" >lda</th>
#       <td id="T_4be0d_row3_col0" class="data row3 col0" >Linear Discriminant Analysis</td>
#       <td id="T_4be0d_row3_col1" class="data row3 col1" >0.9917</td>
#       <td id="T_4be0d_row3_col2" class="data row3 col2" >0.0000</td>
#       <td id="T_4be0d_row3_col3" class="data row3 col3" >0.9917</td>
#       <td id="T_4be0d_row3_col4" class="data row3 col4" >0.9933</td>
#       <td id="T_4be0d_row3_col5" class="data row3 col5" >0.9917</td>
#       <td id="T_4be0d_row3_col6" class="data row3 col6" >0.9874</td>
#       <td id="T_4be0d_row3_col7" class="data row3 col7" >0.9883</td>
#       <td id="T_4be0d_row3_col8" class="data row3 col8" >0.0400</td>
#     </tr>
#     <tr>
#       <th id="T_4be0d_level0_row4" class="row_heading level0 row4" >qda</th>
#       <td id="T_4be0d_row4_col0" class="data row4 col0" >Quadratic Discriminant Analysis</td>
#       <td id="T_4be0d_row4_col1" class="data row4 col1" >0.9846</td>
#       <td id="T_4be0d_row4_col2" class="data row4 col2" >0.0000</td>
#       <td id="T_4be0d_row4_col3" class="data row4 col3" >0.9846</td>
#       <td id="T_4be0d_row4_col4" class="data row4 col4" >0.9872</td>
#       <td id="T_4be0d_row4_col5" class="data row4 col5" >0.9843</td>
#       <td id="T_4be0d_row4_col6" class="data row4 col6" >0.9765</td>
#       <td id="T_4be0d_row4_col7" class="data row4 col7" >0.9781</td>
#       <td id="T_4be0d_row4_col8" class="data row4 col8" >0.0450</td>
#     </tr>
#     <tr>
#       <th id="T_4be0d_level0_row5" class="row_heading level0 row5" >lightgbm</th>
#       <td id="T_4be0d_row5_col0" class="data row5 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_4be0d_row5_col1" class="data row5 col1" >0.9846</td>
#       <td id="T_4be0d_row5_col2" cl
# 2024/09/19 21:57:01 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2024/09/19 21:57:02 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2024/09/19 21:57:02 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2024/09/19 21:57:03 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2024/09/19 21:57:03 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2024/09/19 21:57:03 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2024/09/19 21:57:04 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2024/09/19 21:57:04 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2024/09/19 21:57:04 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2024/09/19 21:57:04 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2024/09/19 21:57:05 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2024/09/19 21:57:05 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2024/09/19 21:57:05 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2024/09/19 21:57:06 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2024/09/19 21:57:06 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2024/09/19 21:57:06 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.

# %% [markdown]
# # Best model prediction

# %%
# predict on test set
holdout_pred = predict_model(best)
# Out:
# <style type="text/css">
# </style>
# <table id="T_48f72">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_48f72_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_48f72_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_48f72_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_48f72_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_48f72_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_48f72_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_48f72_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_48f72_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_48f72_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_48f72_row0_col0" class="data row0 col0" >Extra Trees Classifier</td>
#       <td id="T_48f72_row0_col1" class="data row0 col1" >0.9815</td>
#       <td id="T_48f72_row0_col2" class="data row0 col2" >1.0000</td>
#       <td id="T_48f72_row0_col3" class="data row0 col3" >0.9815</td>
#       <td id="T_48f72_row0_col4" class="data row0 col4" >0.9825</td>
#       <td id="T_48f72_row0_col5" class="data row0 col5" >0.9815</td>
#       <td id="T_48f72_row0_col6" class="data row0 col6" >0.9720</td>
#       <td id="T_48f72_row0_col7" class="data row0 col7" >0.9725</td>
#     </tr>
#   </tbody>
# </table>

# %%
holdout_pred.head()
# Out:
#      alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 19     13.64        3.10  2.56          15.200000      116.0           2.70
# 28     13.87        1.90  2.80          19.400000      107.0           2.95
# 58     13.72        1.43  2.50          16.700001      108.0           3.40
# 102    12.34        2.45  2.46          21.000000       98.0           2.56
# 48     14.10        2.02  2.40          18.799999      103.0           2.75
#
#      flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 19         3.03                  0.17             1.66              5.1  0.96
# 28         2.97                  0.37             1.76              4.5  1.25
# 58         3.67                  0.19             2.04              6.8  0.89
# 102        2.11                  0.34             1.31              2.8  0.80
# 48         2.92                  0.32             2.38              6.2  1.07
#
#      od280_od315_of_diluted_wines  proline  target  prediction_label  \
# 19                           3.36    845.0       0                 0
# 28                           3.40    915.0       0                 0
# 58                           2.87   1285.0       0                 0
# 102                          3.38    438.0       1                 1
# 48                           2.75   1060.0       0                 0
#
#      prediction_score
# 19               0.99
# 28               0.95
# 58               0.96
# 102              0.88
# 48               0.99

# %% [markdown]
# # Save model pipeline

# %%
# save pipeline
save_model(best, 'et_pipeline')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(exclude=None,
#                                      include=['alcohol', 'malic_acid', 'ash',
#                                               'alcalinity_of_ash', 'magnesium',
#                                               'total_phenols', 'flavanoids',
#                                               'nonflavanoid_phenols',
#                                               'proanthocyanins',
#                                               'color_intensity', 'hue',
#                                               'od280_od315_of_diluted_wines',
#                                               'proline'],
#                                      transformer=SimpleImputer(add_indicator=False,...
#                   ExtraTreesClassifier(bootstrap=False, ccp_alpha=0.0,
#                                        class_weight=None, criterion='gini',
#                                        max_depth=None, max_features='sqrt',
#                                        max_leaf_nodes=None, max_samples=None,
#                                        min_impurity_decrease=0.0,
#                                        min_samples_leaf=1, min_samples_split=2,
#                                        min_weight_fraction_leaf=0.0,
#                                        monotonic_cst=None, n_estimators=100,
#                                        n_jobs=-1, oob_score=False,
#                                        random_state=123, verbose=0,
#                                        warm_start=False))],
#           verbose=False),
#  'et_pipeline.pkl')

# %% [markdown]
# # Load model pipeline

# %%
loaded_best_pipeline = load_model('et_pipeline')
loaded_best_pipeline
# Out:
# Transformation Pipeline and Model Successfully Loaded
# Pipeline(memory=FastMemory(location=/tmp/joblib),
#          steps=[('numerical_imputer',
#                  TransformerWrapper(exclude=None,
#                                     include=['alcohol', 'malic_acid', 'ash',
#                                              'alcalinity_of_ash', 'magnesium',
#                                              'total_phenols', 'flavanoids',
#                                              'nonflavanoid_phenols',
#                                              'proanthocyanins',
#                                              'color_intensity', 'hue',
#                                              'od280_od315_of_diluted_wines',
#                                              'proline'],
#                                     transformer=SimpleImputer(add_indic...
#                  ExtraTreesClassifier(bootstrap=False, ccp_alpha=0.0,
#                                       class_weight=None, criterion='gini',
#                                       max_depth=None, max_features='sqrt',
#                                       max_leaf_nodes=None, max_samples=None,
#                                       min_impurity_decrease=0.0,
#                                       min_samples_leaf=1, min_samples_split=2,
#                                       min_weight_fraction_leaf=0.0,
#                                       monotonic_cst=None, n_estimators=100,
#                                       n_jobs=-1, oob_score=False,
#                                       random_state=123, verbose=0,
#                                       warm_start=False))],
#          verbose=False)

# %% [markdown]
# # Get config

# %%
get_config()
# Out:
# {'USI',
#  'X',
#  'X_test',
#  'X_test_transformed',
#  'X_train',
#  'X_train_transformed',
#  'X_transformed',
#  '_available_plots',
#  '_ml_usecase',
#  'data',
#  'dataset',
#  'dataset_transformed',
#  'exp_id',
#  'exp_name_log',
#  'fix_imbalance',
#  'fold_generator',
#  'fold_groups_param',
#  'fold_shuffle_param',
#  'gpu_n_jobs_param',
#  'gpu_param',
#  'html_param',
#  'idx',
#  'is_multiclass',
#  'log_plots_param',
#  'logging_param',
#  'memory',
#  'n_jobs_param',
#  'pipeline',
#  'seed',
#  'target_param',
#  'test',
#  'test_transformed',
#  'train',
#  'train_transformed',
#  'variable_and_property_keys',
#  'variables',
#  'y',
#  'y_test',
#  'y_test_transformed',
#  'y_train',
#  'y_train_transformed',
#  'y_transformed'}

# %% [markdown]
# # Mlflow

# %%
# !mlflow ui --port 5001

# %% [markdown]
# # Creating json for testing (optional)

# %%
'''
import json

def save_json(dataframe, filename):
    """Converts a DataFrame to a JSON file."""
    json_str = dataframe.to_json(orient='records')
    formatted_json = json.dumps(json.loads(json_str), indent=4)
    with open(filename, 'w') as file:
        file.write(formatted_json)

def prepare_and_save_data(X_test, y_test):
    """Prepares data by concatenating, filtering, and saving to JSON files."""
    df = pd.concat([X_test, y_test], axis=1)
    for target in range(3):
        target_df = df[df['target'] == target].drop('target', axis=1)
        save_json(target_df, f'target_{target}.json')
'''

# %%
'''
X_test = get_config('X_test')
y_test = get_config('y_test')

prepare_and_save_data(X_test, y_test)
'''
